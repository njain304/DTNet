# %%
from __future__ import print_function
import argparse
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms

from datasets import limits

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(1, 10, kernel_size=5)
        self.conv2 = nn.Conv2d(10, 20, kernel_size=5)
        self.conv2_drop = nn.Dropout2d()
        self.fc1 = nn.Linear(320, 50)
        self.fc2 = nn.Linear(50, 10)

    def forward(self, x):
        x = F.relu(F.max_pool2d(self.conv1(x), 2))
        x = F.relu(F.max_pool2d(self.conv2_drop(self.conv2(x)), 2))
        x = x.view(-1, 320)
        x = F.relu(self.fc1(x))
        x = F.dropout(x, training=self.training)
        x = self.fc2(x)
        return F.log_softmax(x, dim=1)

def train(model, device, train_loader, optimizer, epoch):
    model.train()
    for batch_idx, (data, target) in enumerate(train_loader):
        data, target = data.to(device), target.to(device)
        optimizer.zero_grad()
        #print(data.size())
        output = model(data)
        loss = F.nll_loss(output, target)
        loss.backward()
        optimizer.step()
        if batch_idx % log_interval == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), loss.item()))

def test(model, device, test_loader):
    model.eval()
    test_loss = 0
    correct = 0
    with torch.no_grad():
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)
            output = model(data)
            test_loss += F.nll_loss(output, target, reduction='sum').item() # sum up batch loss
            pred = output.max(1, keepdim=True)[1] # get the index of the max log-probability
            correct += pred.eq(target.view_as(pred)).sum().item()

    test_loss /= len(test_loader.dataset)
    print('\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
        test_loss, correct, len(test_loader.dataset),
        100. * correct / len(test_loader.dataset)))

# %%
use_cuda = torch.cuda.is_available()
seed = 1
torch.manual_seed(seed)
device = torch.device("cuda" if use_cuda else "cpu")
kwargs = {'num_workers': 1, 'pin_memory': True} if use_cuda else {}
log_interval = 50

# %%
train_loader = torch.utils.data.DataLoader(
    limits.LimitDataset(datasets.MNIST('./data/mnist', train=True, download=False,
                   transform=transforms.Compose([
                       transforms.ToTensor(),
                       transforms.Normalize((0.1307,), (0.3081,))
                   ])), 1000),batch_size=128, shuffle=True, **kwargs)

# %%
test_loader = torch.utils.data.DataLoader(
    limits.LimitDataset(datasets.MNIST('./data/mnist', train=False, transform=transforms.Compose([
                       transforms.ToTensor(),
                       transforms.Normalize((0.1307,), (0.3081,))
                   ])), 500),
    batch_size=128, shuffle=True, **kwargs)

# %%
model = Net().to(device)
optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.5)

# %%
epochs = 200
for epoch in range(1, epochs + 1):
    train(model, device, train_loader, optimizer, epoch)
    test(model, device, test_loader)
# Out:
# Train Epoch: 1 [0/1000 (0%)]	Loss: 2.343734
#
# Test set: Average loss: 2.2937, Accuracy: 69/500 (14%)
#
# Train Epoch: 2 [0/1000 (0%)]	Loss: 2.291720
#
# Test set: Average loss: 2.2802, Accuracy: 71/500 (14%)
#
# Train Epoch: 3 [0/1000 (0%)]	Loss: 2.277281
#
# Test set: Average loss: 2.2691, Accuracy: 77/500 (15%)
#
# Train Epoch: 4 [0/1000 (0%)]	Loss: 2.244127
#
# Test set: Average loss: 2.2588, Accuracy: 87/500 (17%)
#
# Train Epoch: 5 [0/1000 (0%)]	Loss: 2.264951
#
# Test set: Average loss: 2.2449, Accuracy: 114/500 (23%)
#
# Train Epoch: 6 [0/1000 (0%)]	Loss: 2.269098
#
# Test set: Average loss: 2.2253, Accuracy: 141/500 (28%)
#
# Train Epoch: 7 [0/1000 (0%)]	Loss: 2.229976
#
# Test set: Average loss: 2.2019, Accuracy: 160/500 (32%)
#
# Train Epoch: 8 [0/1000 (0%)]	Loss: 2.227368
#
# Test set: Average loss: 2.1719, Accuracy: 178/500 (36%)
#
# Train Epoch: 9 [0/1000 (0%)]	Loss: 2.207919
#
# Test set: Average loss: 2.1309, Accuracy: 191/500 (38%)
#
# Train Epoch: 10 [0/1000 (0%)]	Loss: 2.075113
#
# Test set: Average loss: 2.0755, Accuracy: 218/500 (44%)
#
# Train Epoch: 11 [0/1000 (0%)]	Loss: 2.092442
#
# Test set: Average loss: 2.0110, Accuracy: 224/500 (45%)
#
# Train Epoch: 12 [0/1000 (0%)]	Loss: 2.017612
#
# Test set: Average loss: 1.9226, Accuracy: 243/500 (49%)
#
# Train Epoch: 13 [0/1000 (0%)]	Loss: 2.006962
#
# Test set: Average loss: 1.8287, Accuracy: 252/500 (50%)
#
# Train Epoch: 14 [0/1000 (0%)]	Loss: 1.842978
#
# Test set: Average loss: 1.7224, Accuracy: 268/500 (54%)
#
# Train Epoch: 15 [0/1000 (0%)]	Loss: 1.719107
#
# Test set: Average loss: 1.6130, Accuracy: 290/500 (58%)
#
# Train Epoch: 16 [0/1000 (0%)]	Loss: 1.607063
#
# Test set: Average loss: 1.4944, Accuracy: 307/500 (61%)
#
# Train Epoch: 17 [0/1000 (0%)]	Loss: 1.629047
#
# Test set: Average loss: 1.4061, Accuracy: 323/500 (65%)
#
# Train Epoch: 18 [0/1000 (0%)]	Loss: 1.533004
#
# Test set: Average loss: 1.3111, Accuracy: 334/500 (67%)
#
# Train Epoch: 19 [0/1000 (0%)]	Loss: 1.453140
#
# Test set: Average loss: 1.2445, Accuracy: 349/500 (70%)
#
# Train Epoch: 20 [0/1000 (0%)]	Loss: 1.390654
#
# Test set: Average loss: 1.1435, Accuracy: 357/500 (71%)
#
# Train Epoch: 21 [0/1000 (0%)]	Loss: 1.371722
#
# Test set: Average loss: 1.0533, Accuracy: 361/500 (72%)
#
# Train Epoch: 22 [0/1000 (0%)]	Loss: 1.213407
#
# Test set: Average loss: 0.9959, Accuracy: 372/500 (74%)
#
# Train Epoch: 23 [0/1000 (0%)]	Loss: 1.196482
#
# Test set: Average loss: 0.9393, Accuracy: 376/500 (75%)
#
# Train Epoch: 24 [0/1000 (0%)]	Loss: 1.143837
#
# Test set: Average loss: 0.8905, Accuracy: 379/500 (76%)
#
# Train Epoch: 25 [0/1000 (0%)]	Loss: 1.057898
#
# Test set: Average loss: 0.8516, Accuracy: 382/500 (76%)
#
# Train Epoch: 26 [0/1000 (0%)]	Loss: 1.033024
#
# Test set: Average loss: 0.7978, Accuracy: 390/500 (78%)
#
# Train Epoch: 27 [0/1000 (0%)]	Loss: 1.059389
#
# Test set: Average loss: 0.7648, Accuracy: 391/500 (78%)
#
# Train Epoch: 28 [0/1000 (0%)]	Loss: 0.858250
#
# Test set: Average loss: 0.7542, Accuracy: 389/500 (78%)
#
# Train Epoch: 29 [0/1000 (0%)]	Loss: 0.892120
#
# Test set: Average loss: 0.7054, Accuracy: 400/500 (80%)
#
# Train Epoch: 30 [0/1000 (0%)]	Loss: 1.031340
#
# Test set: Average loss: 0.6923, Accuracy: 400/500 (80%)
#
# Train Epoch: 31 [0/1000 (0%)]	Loss: 0.953771
#
# Test set: Average loss: 0.6570, Accuracy: 404/500 (81%)
#
# Train Epoch: 32 [0/1000 (0%)]	Loss: 0.870291
#
# Test set: Average loss: 0.6513, Accuracy: 409/500 (82%)
#
# Train Epoch: 33 [0/1000 (0%)]	Loss: 0.898645
#
# Test set: Average loss: 0.6305, Accuracy: 410/500 (82%)
#
# Train Epoch: 34 [0/1000 (0%)]	Loss: 0.936739
#
# Test set: Average loss: 0.6232, Accuracy: 412/500 (82%)
#
# Train Epoch: 35 [0/1000 (0%)]	Loss: 0.872904
#
# Test set: Average loss: 0.6072, Accuracy: 410/500 (82%)
#
# Train Epoch: 36 [0/1000 (0%)]	Loss: 0.783768
#
# Test set: Average loss: 0.5893, Accuracy: 405/500 (81%)
#
# Train Epoch: 37 [0/1000 (0%)]	Loss: 0.678400
#
# Test set: Average loss: 0.5794, Accuracy: 418/500 (84%)
#
# Train Epoch: 38 [0/1000 (0%)]	Loss: 0.788733
#
# Test set: Average loss: 0.5532, Accuracy: 418/500 (84%)
#
# Train Epoch: 39 [0/1000 (0%)]	Loss: 0.900241
#
# Test set: Average loss: 0.5545, Accuracy: 418/500 (84%)
#
# Train Epoch: 40 [0/1000 (0%)]	Loss: 0.627302
#
# Test set: Average loss: 0.5457, Accuracy: 421/500 (84%)
#
# Train Epoch: 41 [0/1000 (0%)]	Loss: 0.784345
#
# Test set: Average loss: 0.5252, Accuracy: 422/500 (84%)
#
# Train Epoch: 42 [0/1000 (0%)]	Loss: 0.765712
#
# Test set: Average loss: 0.5208, Accuracy: 427/500 (85%)
#
# Train Epoch: 43 [0/1000 (0%)]	Loss: 0.777079
#
# Test set: Average loss: 0.5089, Accuracy: 423/500 (85%)
#
# Train Epoch: 44 [0/1000 (0%)]	Loss: 0.661810
#
# Test set: Average loss: 0.5097, Accuracy: 421/500 (84%)
#
# Train Epoch: 45 [0/1000 (0%)]	Loss: 0.640420
#
# Test set: Average loss: 0.4979, Accuracy: 425/500 (85%)
#
# Train Epoch: 46 [0/1000 (0%)]	Loss: 0.648799
#
# Test set: Average loss: 0.4925, Accuracy: 426/500 (85%)
#
# Train Epoch: 47 [0/1000 (0%)]	Loss: 0.494480
#
# Test set: Average loss: 0.4769, Accuracy: 426/500 (85%)
#
# Train Epoch: 48 [0/1000 (0%)]	Loss: 0.633891
#
# Test set: Average loss: 0.4554, Accuracy: 427/500 (85%)
#
# Train Epoch: 49 [0/1000 (0%)]	Loss: 0.813704
#
# Test set: Average loss: 0.4591, Accuracy: 426/500 (85%)
#
# Train Epoch: 50 [0/1000 (0%)]	Loss: 0.530046
#
# Test set: Average loss: 0.4558, Accuracy: 431/500 (86%)
#
# Train Epoch: 51 [0/1000 (0%)]	Loss: 0.611612
#
# Test set: Average loss: 0.4598, Accuracy: 432/500 (86%)
#
# Train Epoch: 52 [0/1000 (0%)]	Loss: 0.595021
#
# Test set: Average loss: 0.4496, Accuracy: 430/500 (86%)
#
# Train Epoch: 53 [0/1000 (0%)]	Loss: 0.653203
#
# Test set: Average loss: 0.4497, Accuracy: 430/500 (86%)
#
# Train Epoch: 54 [0/1000 (0%)]	Loss: 0.507505
#
# Test set: Average loss: 0.4310, Accuracy: 437/500 (87%)
#
# Train Epoch: 55 [0/1000 (0%)]	Loss: 0.591483
#
# Test set: Average loss: 0.4224, Accuracy: 437/500 (87%)
#
# Train Epoch: 56 [0/1000 (0%)]	Loss: 0.547060
#
# Test set: Average loss: 0.4146, Accuracy: 437/500 (87%)
#
# Train Epoch: 57 [0/1000 (0%)]	Loss: 0.430222
#
# Test set: Average loss: 0.4197, Accuracy: 434/500 (87%)
#
# Train Epoch: 58 [0/1000 (0%)]	Loss: 0.642268
#
# Test set: Average loss: 0.4040, Accuracy: 437/500 (87%)
#
# Train Epoch: 59 [0/1000 (0%)]	Loss: 0.580227
#
# Test set: Average loss: 0.3990, Accuracy: 439/500 (88%)
#
# Train Epoch: 60 [0/1000 (0%)]	Loss: 0.489314
#
# Test set: Average loss: 0.4012, Accuracy: 437/500 (87%)
#
# Train Epoch: 61 [0/1000 (0%)]	Loss: 0.510995
#
# Test set: Average loss: 0.3952, Accuracy: 440/500 (88%)
#
# Train Epoch: 62 [0/1000 (0%)]	Loss: 0.412121
#
# Test set: Average loss: 0.3920, Accuracy: 440/500 (88%)
#
# Train Epoch: 63 [0/1000 (0%)]	Loss: 0.673636
#
# Test set: Average loss: 0.3822, Accuracy: 441/500 (88%)
#
# Train Epoch: 64 [0/1000 (0%)]	Loss: 0.477291
#
# Test set: Average loss: 0.3820, Accuracy: 441/500 (88%)
#
# Train Epoch: 65 [0/1000 (0%)]	Loss: 0.496485
#
# Test set: Average loss: 0.3846, Accuracy: 440/500 (88%)
#
# Train Epoch: 66 [0/1000 (0%)]	Loss: 0.524446
#
# Test set: Average loss: 0.3701, Accuracy: 442/500 (88%)
#
# Train Epoch: 67 [0/1000 (0%)]	Loss: 0.484623
#
# Test set: Average loss: 0.3719, Accuracy: 442/500 (88%)
#
# Train Epoch: 68 [0/1000 (0%)]	Loss: 0.586590
#
# Test set: Average loss: 0.3646, Accuracy: 442/500 (88%)
#
# Train Epoch: 69 [0/1000 (0%)]	Loss: 0.602457
#
# Test set: Average loss: 0.3779, Accuracy: 441/500 (88%)
#
# Train Epoch: 70 [0/1000 (0%)]	Loss: 0.319002
#
# Test set: Average loss: 0.3575, Accuracy: 444/500 (89%)
#
# Train Epoch: 71 [0/1000 (0%)]	Loss: 0.406738
#
# Test set: Average loss: 0.3655, Accuracy: 441/500 (88%)
#
# Train Epoch: 72 [0/1000 (0%)]	Loss: 0.509033
#
# Test set: Average loss: 0.3477, Accuracy: 444/500 (89%)
#
# Train Epoch: 73 [0/1000 (0%)]	Loss: 0.425697
#
# Test set: Average loss: 0.3667, Accuracy: 442/500 (88%)
#
# Train Epoch: 74 [0/1000 (0%)]	Loss: 0.469994
#
# Test set: Average loss: 0.3528, Accuracy: 445/500 (89%)
#
# Train Epoch: 75 [0/1000 (0%)]	Loss: 0.486451
#
# Test set: Average loss: 0.3499, Accuracy: 448/500 (90%)
#
# Train Epoch: 76 [0/1000 (0%)]	Loss: 0.404342
#
# Test set: Average loss: 0.3437, Accuracy: 445/500 (89%)
#
# Train Epoch: 77 [0/1000 (0%)]	Loss: 0.447865
#
# Test set: Average loss: 0.3357, Accuracy: 442/500 (88%)
#
# Train Epoch: 78 [0/1000 (0%)]	Loss: 0.553720
#
# Test set: Average loss: 0.3413, Accuracy: 446/500 (89%)
#
# Train Epoch: 79 [0/1000 (0%)]	Loss: 0.520684
#
# Test set: Average loss: 0.3592, Accuracy: 445/500 (89%)
#
# Train Epoch: 80 [0/1000 (0%)]	Loss: 0.529310
#
# Test set: Average loss: 0.3374, Accuracy: 446/500 (89%)
# Train Epoch: 81 [0/1000 (0%)]	Loss: 0.422996
#
# Test set: Average loss: 0.3361, Accuracy: 445/500 (89%)
#
# Train Epoch: 82 [0/1000 (0%)]	Loss: 0.474287
#
# Test set: Average loss: 0.3279, Accuracy: 446/500 (89%)
#
# Train Epoch: 83 [0/1000 (0%)]	Loss: 0.479390
#
# Test set: Average loss: 0.3356, Accuracy: 448/500 (90%)
#
# Train Epoch: 84 [0/1000 (0%)]	Loss: 0.562410
#
# Test set: Average loss: 0.3311, Accuracy: 453/500 (91%)
#
# Train Epoch: 85 [0/1000 (0%)]	Loss: 0.497106
#
# Test set: Average loss: 0.3377, Accuracy: 447/500 (89%)
#
# Train Epoch: 86 [0/1000 (0%)]	Loss: 0.315438
#
# Test set: Average loss: 0.3282, Accuracy: 445/500 (89%)
#
# Train Epoch: 87 [0/1000 (0%)]	Loss: 0.478883
#
# Test set: Average loss: 0.3226, Accuracy: 449/500 (90%)
#
# Train Epoch: 88 [0/1000 (0%)]	Loss: 0.421620
#
# Test set: Average loss: 0.3182, Accuracy: 450/500 (90%)
#
# Train Epoch: 89 [0/1000 (0%)]	Loss: 0.289578
#
# Test set: Average loss: 0.3149, Accuracy: 451/500 (90%)
#
# Train Epoch: 90 [0/1000 (0%)]	Loss: 0.332408
#
# Test set: Average loss: 0.3136, Accuracy: 451/500 (90%)
#
# Train Epoch: 91 [0/1000 (0%)]	Loss: 0.332746
#
# Test set: Average loss: 0.3181, Accuracy: 449/500 (90%)
#
# Train Epoch: 92 [0/1000 (0%)]	Loss: 0.435713
#
# Test set: Average loss: 0.3186, Accuracy: 450/500 (90%)
#
# Train Epoch: 93 [0/1000 (0%)]	Loss: 0.497515
#
# Test set: Average loss: 0.3206, Accuracy: 450/500 (90%)
#
# Train Epoch: 94 [0/1000 (0%)]	Loss: 0.402587
#
# Test set: Average loss: 0.3104, Accuracy: 452/500 (90%)
#
# Train Epoch: 95 [0/1000 (0%)]	Loss: 0.415925
#
# Test set: Average loss: 0.3159, Accuracy: 451/500 (90%)
#
# Train Epoch: 96 [0/1000 (0%)]	Loss: 0.384188
#
# Test set: Average loss: 0.2990, Accuracy: 453/500 (91%)
#
# Train Epoch: 97 [0/1000 (0%)]	Loss: 0.379216
#
# Test set: Average loss: 0.2957, Accuracy: 452/500 (90%)
#
# Train Epoch: 98 [0/1000 (0%)]	Loss: 0.393570
#
# Test set: Average loss: 0.2925, Accuracy: 455/500 (91%)
#
# Train Epoch: 99 [0/1000 (0%)]	Loss: 0.306573
#
# Test set: Average loss: 0.2867, Accuracy: 455/500 (91%)
#
# Train Epoch: 100 [0/1000 (0%)]	Loss: 0.427259
#
# Test set: Average loss: 0.2847, Accuracy: 457/500 (91%)
#
# Train Epoch: 101 [0/1000 (0%)]	Loss: 0.340900
#
# Test set: Average loss: 0.2893, Accuracy: 452/500 (90%)
#
# Train Epoch: 102 [0/1000 (0%)]	Loss: 0.348580
#
# Test set: Average loss: 0.2888, Accuracy: 451/500 (90%)
#
# Train Epoch: 103 [0/1000 (0%)]	Loss: 0.465564
#
# Test set: Average loss: 0.2813, Accuracy: 454/500 (91%)
#
# Train Epoch: 104 [0/1000 (0%)]	Loss: 0.413730
#
# Test set: Average loss: 0.2758, Accuracy: 456/500 (91%)
#
# Train Epoch: 105 [0/1000 (0%)]	Loss: 0.345223
#
# Test set: Average loss: 0.2833, Accuracy: 459/500 (92%)
#
# Train Epoch: 106 [0/1000 (0%)]	Loss: 0.325434
#
# Test set: Average loss: 0.2752, Accuracy: 455/500 (91%)
#
# Train Epoch: 107 [0/1000 (0%)]	Loss: 0.264978
#
# Test set: Average loss: 0.2736, Accuracy: 456/500 (91%)
#
# Train Epoch: 108 [0/1000 (0%)]	Loss: 0.350327
#
# Test set: Average loss: 0.2798, Accuracy: 456/500 (91%)
#
# Train Epoch: 109 [0/1000 (0%)]	Loss: 0.334084
#
# Test set: Average loss: 0.2753, Accuracy: 458/500 (92%)
#
# Train Epoch: 110 [0/1000 (0%)]	Loss: 0.334527
#
# Test set: Average loss: 0.2769, Accuracy: 458/500 (92%)
#
# Train Epoch: 111 [0/1000 (0%)]	Loss: 0.301393
#
# Test set: Average loss: 0.2755, Accuracy: 458/500 (92%)
#
# Train Epoch: 112 [0/1000 (0%)]	Loss: 0.344047
#
# Test set: Average loss: 0.2669, Accuracy: 458/500 (92%)
#
# Train Epoch: 113 [0/1000 (0%)]	Loss: 0.432958
#
# Test set: Average loss: 0.2702, Accuracy: 459/500 (92%)
#
# Train Epoch: 114 [0/1000 (0%)]	Loss: 0.393127
#
# Test set: Average loss: 0.2692, Accuracy: 456/500 (91%)
#
# Train Epoch: 115 [0/1000 (0%)]	Loss: 0.289009
#
# Test set: Average loss: 0.2657, Accuracy: 455/500 (91%)
#
# Train Epoch: 116 [0/1000 (0%)]	Loss: 0.350579
#
# Test set: Average loss: 0.2622, Accuracy: 460/500 (92%)
#
# Train Epoch: 117 [0/1000 (0%)]	Loss: 0.335201
#
# Test set: Average loss: 0.2588, Accuracy: 464/500 (93%)
#
# Train Epoch: 118 [0/1000 (0%)]	Loss: 0.245505
#
# Test set: Average loss: 0.2614, Accuracy: 459/500 (92%)
#
# Train Epoch: 119 [0/1000 (0%)]	Loss: 0.362460
#
# Test set: Average loss: 0.2568, Accuracy: 459/500 (92%)
#
# Train Epoch: 120 [0/1000 (0%)]	Loss: 0.327821
#
# Test set: Average loss: 0.2674, Accuracy: 455/500 (91%)
#
# Train Epoch: 121 [0/1000 (0%)]	Loss: 0.295437
#
# Test set: Average loss: 0.2634, Accuracy: 461/500 (92%)
#
# Train Epoch: 122 [0/1000 (0%)]	Loss: 0.378441
#
# Test set: Average loss: 0.2607, Accuracy: 455/500 (91%)
#
# Train Epoch: 123 [0/1000 (0%)]	Loss: 0.321337
#
# Test set: Average loss: 0.2537, Accuracy: 462/500 (92%)
#
# Train Epoch: 124 [0/1000 (0%)]	Loss: 0.282008
#
# Test set: Average loss: 0.2596, Accuracy: 459/500 (92%)
#
# Train Epoch: 125 [0/1000 (0%)]	Loss: 0.172519
#
# Test set: Average loss: 0.2622, Accuracy: 463/500 (93%)
#
# Train Epoch: 126 [0/1000 (0%)]	Loss: 0.298720
#
# Test set: Average loss: 0.2588, Accuracy: 462/500 (92%)
#
# Train Epoch: 127 [0/1000 (0%)]	Loss: 0.290773
#
# Test set: Average loss: 0.2599, Accuracy: 458/500 (92%)
#
# Train Epoch: 128 [0/1000 (0%)]	Loss: 0.304881
#
# Test set: Average loss: 0.2597, Accuracy: 459/500 (92%)
#
# Train Epoch: 129 [0/1000 (0%)]	Loss: 0.329254
#
# Test set: Average loss: 0.2564, Accuracy: 461/500 (92%)
#
# Train Epoch: 130 [0/1000 (0%)]	Loss: 0.324799
#
# Test set: Average loss: 0.2537, Accuracy: 460/500 (92%)
#
# Train Epoch: 131 [0/1000 (0%)]	Loss: 0.434146
#
# Test set: Average loss: 0.2546, Accuracy: 462/500 (92%)
#
# Train Epoch: 132 [0/1000 (0%)]	Loss: 0.194812
#
# Test set: Average loss: 0.2487, Accuracy: 462/500 (92%)
#
# Train Epoch: 133 [0/1000 (0%)]	Loss: 0.385293
#
# Test set: Average loss: 0.2508, Accuracy: 462/500 (92%)
#
# Train Epoch: 134 [0/1000 (0%)]	Loss: 0.191011
#
# Test set: Average loss: 0.2430, Accuracy: 463/500 (93%)
#
# Train Epoch: 135 [0/1000 (0%)]	Loss: 0.188993
#
# Test set: Average loss: 0.2457, Accuracy: 459/500 (92%)
#
# Train Epoch: 136 [0/1000 (0%)]	Loss: 0.299387
#
# Test set: Average loss: 0.2508, Accuracy: 460/500 (92%)
#
# Train Epoch: 137 [0/1000 (0%)]	Loss: 0.338180
#
# Test set: Average loss: 0.2524, Accuracy: 462/500 (92%)
#
# Train Epoch: 138 [0/1000 (0%)]	Loss: 0.216481
#
# Test set: Average loss: 0.2456, Accuracy: 462/500 (92%)
#
# Train Epoch: 139 [0/1000 (0%)]	Loss: 0.372765
#
# Test set: Average loss: 0.2390, Accuracy: 462/500 (92%)
#
# Train Epoch: 140 [0/1000 (0%)]	Loss: 0.234969
#
# Test set: Average loss: 0.2443, Accuracy: 462/500 (92%)
#
# Train Epoch: 141 [0/1000 (0%)]	Loss: 0.219195
#
# Test set: Average loss: 0.2463, Accuracy: 463/500 (93%)
#
# Train Epoch: 142 [0/1000 (0%)]	Loss: 0.309773
#
# Test set: Average loss: 0.2373, Accuracy: 466/500 (93%)
#
# Train Epoch: 143 [0/1000 (0%)]	Loss: 0.150362
#
# Test set: Average loss: 0.2380, Accuracy: 461/500 (92%)
#
# Train Epoch: 144 [0/1000 (0%)]	Loss: 0.322162
#
# Test set: Average loss: 0.2469, Accuracy: 457/500 (91%)
#
# Train Epoch: 145 [0/1000 (0%)]	Loss: 0.254525
#
# Test set: Average loss: 0.2399, Accuracy: 459/500 (92%)
#
# Train Epoch: 146 [0/1000 (0%)]	Loss: 0.239197
#
# Test set: Average loss: 0.2451, Accuracy: 462/500 (92%)
#
# Train Epoch: 147 [0/1000 (0%)]	Loss: 0.275743
#
# Test set: Average loss: 0.2446, Accuracy: 461/500 (92%)
#
# Train Epoch: 148 [0/1000 (0%)]	Loss: 0.248896
#
# Test set: Average loss: 0.2459, Accuracy: 459/500 (92%)
#
# Train Epoch: 149 [0/1000 (0%)]	Loss: 0.254300
#
# Test set: Average loss: 0.2436, Accuracy: 463/500 (93%)
#
# Train Epoch: 150 [0/1000 (0%)]	Loss: 0.321583
#
# Test set: Average loss: 0.2425, Accuracy: 460/500 (92%)
#
# Train Epoch: 151 [0/1000 (0%)]	Loss: 0.337676
#
# Test set: Average loss: 0.2509, Accuracy: 462/500 (92%)
#
# Train Epoch: 152 [0/1000 (0%)]	Loss: 0.222749
#
# Test set: Average loss: 0.2461, Accuracy: 463/500 (93%)
#
# Train Epoch: 153 [0/1000 (0%)]	Loss: 0.273536
#
# Test set: Average loss: 0.2395, Accuracy: 464/500 (93%)
#
# Train Epoch: 154 [0/1000 (0%)]	Loss: 0.193749
#
# Test set: Average loss: 0.2345, Accuracy: 462/500 (92%)
#
# Train Epoch: 155 [0/1000 (0%)]	Loss: 0.260161
#
# Test set: Average loss: 0.2431, Accuracy: 462/500 (92%)
#
# Train Epoch: 156 [0/1000 (0%)]	Loss: 0.313893
#
# Test set: Average loss: 0.2332, Accuracy: 466/500 (93%)
#
# Train Epoch: 157 [0/1000 (0%)]	Loss: 0.228625
#
# Test set: Average loss: 0.2319, Accuracy: 465/500 (93%)
#
# Train Epoch: 158 [0/1000 (0%)]	Loss: 0.173498
#
# Test set: Average loss: 0.2290, Accuracy: 465/500 (93%)
#
# Train Epoch: 159 [0/1000 (0%)]	Loss: 0.237855
#
# Test set: Average loss: 0.2251, Accuracy: 466/500 (93%)
# Train Epoch: 160 [0/1000 (0%)]	Loss: 0.179624
#
# Test set: Average loss: 0.2333, Accuracy: 463/500 (93%)
#
# Train Epoch: 161 [0/1000 (0%)]	Loss: 0.182809
#
# Test set: Average loss: 0.2277, Accuracy: 465/500 (93%)
#
# Train Epoch: 162 [0/1000 (0%)]	Loss: 0.205753
#
# Test set: Average loss: 0.2229, Accuracy: 464/500 (93%)
#
# Train Epoch: 163 [0/1000 (0%)]	Loss: 0.329354
#
# Test set: Average loss: 0.2216, Accuracy: 464/500 (93%)
#
# Train Epoch: 164 [0/1000 (0%)]	Loss: 0.230445
#
# Test set: Average loss: 0.2292, Accuracy: 465/500 (93%)
#
# Train Epoch: 165 [0/1000 (0%)]	Loss: 0.435869
#
# Test set: Average loss: 0.2265, Accuracy: 464/500 (93%)
#
# Train Epoch: 166 [0/1000 (0%)]	Loss: 0.225904
#
# Test set: Average loss: 0.2319, Accuracy: 464/500 (93%)
#
# Train Epoch: 167 [0/1000 (0%)]	Loss: 0.222477
#
# Test set: Average loss: 0.2222, Accuracy: 462/500 (92%)
#
# Train Epoch: 168 [0/1000 (0%)]	Loss: 0.251170
#
# Test set: Average loss: 0.2278, Accuracy: 466/500 (93%)
#
# Train Epoch: 169 [0/1000 (0%)]	Loss: 0.253001
#
# Test set: Average loss: 0.2327, Accuracy: 465/500 (93%)
#
# Train Epoch: 170 [0/1000 (0%)]	Loss: 0.223393
#
# Test set: Average loss: 0.2249, Accuracy: 465/500 (93%)
#
# Train Epoch: 171 [0/1000 (0%)]	Loss: 0.255721
#
# Test set: Average loss: 0.2287, Accuracy: 465/500 (93%)
#
# Train Epoch: 172 [0/1000 (0%)]	Loss: 0.144627
#
# Test set: Average loss: 0.2292, Accuracy: 464/500 (93%)
#
# Train Epoch: 173 [0/1000 (0%)]	Loss: 0.292140
#
# Test set: Average loss: 0.2305, Accuracy: 463/500 (93%)
#
# Train Epoch: 174 [0/1000 (0%)]	Loss: 0.337669
#
# Test set: Average loss: 0.2238, Accuracy: 466/500 (93%)
#
# Train Epoch: 175 [0/1000 (0%)]	Loss: 0.216128
#
# Test set: Average loss: 0.2223, Accuracy: 465/500 (93%)
#
# Train Epoch: 176 [0/1000 (0%)]	Loss: 0.326386
#
# Test set: Average loss: 0.2172, Accuracy: 465/500 (93%)
#
# Train Epoch: 177 [0/1000 (0%)]	Loss: 0.191514
#
# Test set: Average loss: 0.2284, Accuracy: 462/500 (92%)
#
# Train Epoch: 178 [0/1000 (0%)]	Loss: 0.187372
#
# Test set: Average loss: 0.2239, Accuracy: 466/500 (93%)
#
# Train Epoch: 179 [0/1000 (0%)]	Loss: 0.259604
#
# Test set: Average loss: 0.2220, Accuracy: 464/500 (93%)
#
# Train Epoch: 180 [0/1000 (0%)]	Loss: 0.221950
#
# Test set: Average loss: 0.2200, Accuracy: 465/500 (93%)
#
# Train Epoch: 181 [0/1000 (0%)]	Loss: 0.161631
#
# Test set: Average loss: 0.2227, Accuracy: 465/500 (93%)
#
# Train Epoch: 182 [0/1000 (0%)]	Loss: 0.226316
#
# Test set: Average loss: 0.2284, Accuracy: 466/500 (93%)
#
# Train Epoch: 183 [0/1000 (0%)]	Loss: 0.255959
#
# Test set: Average loss: 0.2214, Accuracy: 465/500 (93%)
#
# Train Epoch: 184 [0/1000 (0%)]	Loss: 0.262488
#
# Test set: Average loss: 0.2184, Accuracy: 467/500 (93%)
#
# Train Epoch: 185 [0/1000 (0%)]	Loss: 0.211193
#
# Test set: Average loss: 0.2143, Accuracy: 466/500 (93%)
#
# Train Epoch: 186 [0/1000 (0%)]	Loss: 0.170691
#
# Test set: Average loss: 0.2192, Accuracy: 468/500 (94%)
#
# Train Epoch: 187 [0/1000 (0%)]	Loss: 0.218420
#
# Test set: Average loss: 0.2211, Accuracy: 467/500 (93%)
#
# Train Epoch: 188 [0/1000 (0%)]	Loss: 0.200293
#
# Test set: Average loss: 0.2167, Accuracy: 465/500 (93%)
#
# Train Epoch: 189 [0/1000 (0%)]	Loss: 0.163962
#
# Test set: Average loss: 0.2116, Accuracy: 466/500 (93%)
#
# Train Epoch: 190 [0/1000 (0%)]	Loss: 0.123349
#
# Test set: Average loss: 0.2179, Accuracy: 467/500 (93%)
#
# Train Epoch: 191 [0/1000 (0%)]	Loss: 0.154739
#
# Test set: Average loss: 0.2190, Accuracy: 466/500 (93%)
#
# Train Epoch: 192 [0/1000 (0%)]	Loss: 0.233117
#
# Test set: Average loss: 0.2224, Accuracy: 467/500 (93%)
#
# Train Epoch: 193 [0/1000 (0%)]	Loss: 0.273329
#
# Test set: Average loss: 0.2207, Accuracy: 466/500 (93%)
#
# Train Epoch: 194 [0/1000 (0%)]	Loss: 0.212643
#
# Test set: Average loss: 0.2198, Accuracy: 465/500 (93%)
#
# Train Epoch: 195 [0/1000 (0%)]	Loss: 0.301220
#
# Test set: Average loss: 0.2237, Accuracy: 467/500 (93%)
#
# Train Epoch: 196 [0/1000 (0%)]	Loss: 0.153706
#
# Test set: Average loss: 0.2192, Accuracy: 465/500 (93%)
#
# Train Epoch: 197 [0/1000 (0%)]	Loss: 0.323780
#
# Test set: Average loss: 0.2173, Accuracy: 467/500 (93%)
#
# Train Epoch: 198 [0/1000 (0%)]	Loss: 0.238793
#
# Test set: Average loss: 0.2166, Accuracy: 466/500 (93%)
#
# Train Epoch: 199 [0/1000 (0%)]	Loss: 0.208907
#
# Test set: Average loss: 0.2203, Accuracy: 465/500 (93%)
#
# Train Epoch: 200 [0/1000 (0%)]	Loss: 0.153186
#
# Test set: Average loss: 0.2210, Accuracy: 463/500 (93%)
